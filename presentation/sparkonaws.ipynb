# %% [markdown]
# # 7 Steps for setting up Apache Spark on a free (or not free) tiered Linux EC2 instance and running PySpark on a Jupyter Notebook Server that you can access on your remote machine
#
# ### Please note--- all of the resources mentioned on this document have been deleted, including the s3 bucket. Also, the keys used to log-in to my now deleted EC2 instance have been deleted. Nothing is secure; never underestimate the abilities of hackers... Finally, the cost for this project ended up being a little over a dollar. If you don't spin down your resources, etc... AWS will eventually charge you for its service.

# %% [markdown]
# # Step 1. Spin up a (free tier) Linux EC2 instance on AWS ; ssh into and update
# ![ssh.png](attachment:ssh.png)

# %% [markdown]
# ![apt_get_update.png](attachment:apt_get_update.png)

# %% [markdown]
# # Step 2. Go to Apache Spark's Website and install Spark on you EC2 instance
# ![spark_download_page.png](attachment:spark_download_page.png)

# %% [markdown]
# ![spark_download.png](attachment:spark_download.png)

# %% [markdown]
# # STEP 3. Untar ; save the folder in /opt
#
# ![untar_spark.png](attachment:untar_spark.png)

# %% [markdown]
# # STEP 4. Make the following installations
#
# ## A.) PIP3
# ![pip3_install.png](attachment:pip3_install.png)

# %% [markdown]
# ## B.) Py4J
# ![install_py4j.png](attachment:install_py4j.png)

# %% [markdown]
# ## C.) Jupyter Notebook
# ![install_jupyter.png](attachment:install_jupyter.png)

# %% [markdown]
# ## D.) JAVA 11
# ![java_install.png](attachment:java_install.png)

# %% [markdown]
# ## E.) SCALA
# ![scala_install.png](attachment:scala_install.png)

# %% [markdown]
# ## F.) AWS Command Line
# ![awscli.png](attachment:awscli.png)

# %% [markdown]
# # STEP 5. Spark Configurations in ~/.profile; includes using Jupyter notebook when launching PySpark
#
# ![spark_configs.png](attachment:spark_configs.png)

# %% [markdown]
# ## A.) Also make sure following edits made to /opt/spark/bin/pyspark

# %% [markdown]
# ![pyspark1.png](attachment:pyspark1.png)

# %% [markdown]
# ### Note: line below is last line of /opt/spark/bin/pyspark; (I used "more pyspark" on the command line to show its contents)
# ![pyspark2.png](attachment:pyspark2.png)

# %% [markdown]
# ## STEP 6. Generate Jupyter config file (can be found in .jupyter folder of home directory); and make configurations as needed. Below are a few I made
# ![configure_jupyter.png](attachment:configure_jupyter.png)

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ![9.png](attachment:9.png)

# %% [markdown]
# ![10.png](attachment:10.png)

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# # STEP 7. Set up security group; for my project only allowed my Local, remote IP address for inbound
# ![securitygroup.png](attachment:securitygroup.png)

# %% [markdown]
# # STEP 7: START SPARK AND LOGIN FROM LOCAL MACHINE; please note, that setting up an s3 bucket and giving the EC2 instance access rights to that s3 bucket are not covered in this write-up. Here is the link that I used to do this though, if interested: https://aws.amazon.com/premiumsupport/knowledge-center/ec2-instance-access-s3-bucket/
#
#
# ![launch_pyspark.png](attachment:launch_pyspark.png)

# %% [markdown]
# ![enter_password.png](attachment:enter_password.png)

# %% [markdown]
# ![import_pyspark.png](attachment:import_pyspark.png)
